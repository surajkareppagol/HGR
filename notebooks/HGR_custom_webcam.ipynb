# %%
import os

import cv2
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
# Out:
# 2024-03-25 21:15:12.394107: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-25 21:15:12.394228: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-25 21:15:12.396690: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-25 21:15:12.406400: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-25 21:15:14.201615: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ```py
# # image = mp.Image.create_from_file("photo.jpg")
#
# # <mediapipe.python._framework_bindings.image.Image object at 0x74b9d96019d0>
# # <mediapipe.python._framework_bindings.image.Image object at 0x7b942db09910>
# ```

# %% [markdown]
# Create a GestureRecognizer object

# %%
model_path = os.path.abspath("../tasks/custom_gestures.task")
recognizer = vision.GestureRecognizer.create_from_model_path(model_path)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1711381518.960391   83285 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1711381518.964114   84124 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.0.3-arch1.2), renderer: Mesa Intel(R) HD Graphics 620 (KBL GT2F)
# W0000 00:00:1711381518.964883   83285 gesture_recognizer_graph.cc:129] Hand Gesture Recognizer contains CPU only ops. Sets HandGestureRecognizerGraph acceleration to Xnnpack.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# Start the webcam and begin capturing

# %%
capture = cv2.VideoCapture(0)
top_gesture = None
rating = None

# %% [markdown]
# Read the frames and recognize the gestures

# %%
while True:
    success, frame = capture.read()

    image = mp.Image(image_format=mp.ImageFormat.SRGB, data=frame)

    recognition_result = recognizer.recognize(image)

    if len(recognition_result.gestures) > 0:
        top_gesture = recognition_result.gestures[0][0]

    if not top_gesture:
        result = "None"
        rating = 0.0
    else:
        result = top_gesture.category_name
        rating = top_gesture.score

    print(f"Gesture recognized: {result} ({rating})")

    cv2.putText(
        frame,
        f"{result}",
        (0, 40),
        cv2.FONT_HERSHEY_PLAIN,
        3.0,
        (0, 0, 0),
        3,
    )
        
    cv2.imshow("img", frame)

    if cv2.waitKey(20) & 0xFF == ord("q"):
        cv2.destroyAllWindows()
        break
# Out:
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized: None (0.0)
# Gesture recognized:  (0.5619462728500366)
# Gesture recognized: none (0.5271158814430237)
# Gesture recognized: none (0.5271158814430237)
# Gesture recognized: none (0.5271158814430237)
# Gesture recognized: none (0.5271158814430237)
# Gesture recognized: none (0.5271158814430237)
# Gesture recognized: none (0.5271158814430237)
# Gesture recognized:  (0.6491754651069641)
# Gesture recognized:  (0.6491754651069641)
# Gesture recognized:  (0.6506319642066956)
# Gesture recognized:  (0.6506319642066956)
# Gesture recognized:  (0.6506319642066956)
# Gesture recognized: none (0.5181972980499268)
# Gesture recognized: none (0.5181972980499268)
# Gesture recognized: none (0.5181972980499268)
# Gesture recognized:  (0.5980303287506104)
# Gesture recognized:  (0.5980303287506104)
# Gesture recognized: none (0.6357471942901611)
# Gesture recognized: none (0.6002934575080872)
# Gesture recognized: none (0.6002934575080872)
# Gesture recognized: none (0.6002934575080872)
# Gesture recognized: none (0.6002934575080872)
# Gesture recognized: none (0.6002934575080872)
# Gesture recognized: none (0.6002934575080872)
# Gesture recognized: none (0.5698026418685913)
# Gesture recognized: none (0.5698026418685913)
# Gesture recognized: none (0.5698026418685913)
# Gesture recognized: none (0.5698026418685913)
# Gesture recognized: none (0.5698026418685913)
# Gesture recognized: none (0.5698026418685913)
# Gesture recognized: none (0.5698026418685913)
# Gesture recognized: none (0.5698026418685913)
# Gesture recognized: none (0.5698026418685913)
# Gesture recognized: none (0.5698026418685913)
# Gesture recognized: none (0.5698026418685913)
# Gesture recognized:  (0.6411603689193726)
# Gesture recognized:  (0.6411603689193726)
# Gesture recognized: none (0.5532954931259155)
# Gesture recognized: none (0.5532954931259155)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.6331406235694885)
# Gesture recognized: none (0.5121376514434814)
# Gesture recognized: none (0.5121376514434814)
# Gesture recognized: none (0.5121376514434814)
# Gesture recognized: none (0.5121376514434814)
# Gesture recognized: none (0.5121376514434814)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized:  (0.6751647591590881)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
# Gesture recognized: paper (0.5523495674133301)
